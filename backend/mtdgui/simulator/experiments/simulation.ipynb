# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging
import networkx 

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])
# Out:
# check env is
# None

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100)
# Out:
# env is
# <simpy.core.Environment object at 0x0000020A51833580>
# check env is
# <simpy.core.Environment object at 0x0000020A51833580>
# Adversary: Start SCAN_HOST at 0.0s.
# MTD: ServiceDiversity triggered 0.0s
# MTD: ServiceDiversity deployed in the network at 0.0s.
# Adversary: Processed SCAN_HOST at 5.0s.
# Adversary: Start ENUM_HOST at 5.0s.
# Adversary: Processed ENUM_HOST at 10.0s.
# Adversary: Start SCAN_PORT at 10.0s.
# Adversary: Processed SCAN_PORT at 35.0s.
# Adversary: Start EXPLOIT_VULN a40d26cc-9976-4685-9dc2-24184fbe1b96 on host 0 at 35.0s.
# Adversary: Processed EXPLOIT_VULN a40d26cc-9976-4685-9dc2-24184fbe1b96 on host 0 at 35.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 66c81206-178e-4078-87b6-3c3ae69a6611 on host 0 at 35.7s.
# Adversary: Processed EXPLOIT_VULN 66c81206-178e-4078-87b6-3c3ae69a6611 on host 0 at 36.9s.
# Adversary: Start EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 0 at 36.9s.
# Adversary: Processed EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 0 at 56.7s.
# Adversary: Start EXPLOIT_VULN 28fdf790-21d8-430c-96de-dc978ae72ec2 on host 0 at 56.7s.
# Adversary: Processed EXPLOIT_VULN 28fdf790-21d8-430c-96de-dc978ae72ec2 on host 0 at 63.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start BRUTE_FORCE at 63.7s.
# MTD: ServiceDiversity finished in 70.2s at 70.2s.
# MTD: Interrupted BRUTE_FORCE at 70.2s!
# Adversary: Restarting with SCAN_PORT at 90.8s!
# Adversary: Start SCAN_PORT at 90.8s.
# Adversary: Processed SCAN_PORT at 115.8s.
# Adversary: Start EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 0 at 115.8s.
# Adversary: Processed EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 0 at 135.5s.
# Adversary: Start EXPLOIT_VULN a2086b60-0f0a-4b8f-a750-7c9e1b82db75 on host 0 at 135.5s.
# Adversary: Processed EXPLOIT_VULN a2086b60-0f0a-4b8f-a750-7c9e1b82db75 on host 0 at 139.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e526de4e-a214-4a70-a741-56cb5e60d334 on host 0 at 139.8s.
# Adversary: Processed EXPLOIT_VULN e526de4e-a214-4a70-a741-56cb5e60d334 on host 0 at 152.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2aa30544-844e-408d-a671-f90a9d49791a on host 0 at 152.0s.
# Adversary: Processed EXPLOIT_VULN 2aa30544-844e-408d-a671-f90a9d49791a on host 0 at 155.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 0 has been compromised at 155.4s!
# Adversary: Start SCAN_NEIGHBOR at 155.4s.
# Adversary: Processed SCAN_NEIGHBOR at 160.4s.
# Adversary: Start ENUM_HOST at 160.4s.
# Adversary: Processed ENUM_HOST at 165.4s.
# Adversary: Start SCAN_PORT at 165.4s.
# Adversary: Processed SCAN_PORT at 190.4s.
# Adversary: Start EXPLOIT_VULN 8b633cfb-3738-47cf-840b-7eabe1ef432c on host 27 at 190.4s.
# Adversary: Processed EXPLOIT_VULN 8b633cfb-3738-47cf-840b-7eabe1ef432c on host 27 at 194.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3dbe3936-3e4f-4d28-8d1a-11fbac512b1f on host 27 at 194.0s.
# Adversary: Processed EXPLOIT_VULN 3dbe3936-3e4f-4d28-8d1a-11fbac512b1f on host 27 at 200.9s.
# Adversary: Start EXPLOIT_VULN f6326b55-af00-46b7-a230-eab3d3989a8b on host 27 at 200.9s.
# MTD: IPShuffle triggered 201.0s
# MTD: IPShuffle deployed in the network at 201.0s.
# Adversary: Processed EXPLOIT_VULN f6326b55-af00-46b7-a230-eab3d3989a8b on host 27 at 210.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d0e015d9-c9d6-430b-b5d9-1a3e72132afc on host 27 at 210.3s.
# Adversary: Processed EXPLOIT_VULN d0e015d9-c9d6-430b-b5d9-1a3e72132afc on host 27 at 213.3s.
# Adversary: Start EXPLOIT_VULN 8b6d9180-2fe7-4486-8668-77e12e86b1e0 on host 27 at 213.3s.
# Adversary: Processed EXPLOIT_VULN 8b6d9180-2fe7-4486-8668-77e12e86b1e0 on host 27 at 221.1s.
# Adversary: Start EXPLOIT_VULN e3609170-1d1f-4158-9359-87af223a9701 on host 27 at 221.1s.
# Adversary: Processed EXPLOIT_VULN e3609170-1d1f-4158-9359-87af223a9701 on host 27 at 229.9s.
# Adversary: Start EXPLOIT_VULN fe3dafa3-9407-48a2-80eb-316ac005b801 on host 27 at 229.9s.
# Adversary: Processed EXPLOIT_VULN fe3dafa3-9407-48a2-80eb-316ac005b801 on host 27 at 237.2s.
# Adversary: Start EXPLOIT_VULN 410b2be6-b204-4f8d-82e8-bd040e7038f2 on host 27 at 237.2s.
# Adversary: Processed EXPLOIT_VULN 410b2be6-b204-4f8d-82e8-bd040e7038f2 on host 27 at 245.6s.
# Adversary: Start EXPLOIT_VULN a7dd832f-fcad-44be-a656-a334386e0ebe on host 27 at 245.6s.
# Adversary: Processed EXPLOIT_VULN a7dd832f-fcad-44be-a656-a334386e0ebe on host 27 at 249.2s.
# Adversary: Host 27 has been compromised at 249.2s!
# Adversary: Start SCAN_NEIGHBOR at 249.2s.
# Adversary: Processed SCAN_NEIGHBOR at 254.2s.
# Adversary: Start ENUM_HOST at 254.2s.
# Adversary: Processed ENUM_HOST at 259.2s.
# Adversary: Start SCAN_PORT at 259.2s.
# Adversary: Processed SCAN_PORT at 284.2s.
# Adversary: Start EXPLOIT_VULN e8673df0-ee84-48be-b811-f0080eb53e94 on host 12 at 284.2s.
# Adversary: Processed EXPLOIT_VULN e8673df0-ee84-48be-b811-f0080eb53e94 on host 12 at 284.9s.
# Adversary: Start EXPLOIT_VULN e8f8a713-acf7-4ef6-b80b-40dd20a91b0d on host 12 at 284.9s.
# Adversary: Processed EXPLOIT_VULN e8f8a713-acf7-4ef6-b80b-40dd20a91b0d on host 12 at 286.1s.
# Adversary: Start EXPLOIT_VULN 3551bb33-2c3f-4752-9eac-b7955fbe7e18 on host 12 at 286.1s.
# Adversary: Processed EXPLOIT_VULN 3551bb33-2c3f-4752-9eac-b7955fbe7e18 on host 12 at 288.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 052ebc39-0692-4ab8-b5ae-8eb0f97a1891 on host 12 at 288.2s.
# Adversary: Processed EXPLOIT_VULN 052ebc39-0692-4ab8-b5ae-8eb0f97a1891 on host 12 at 290.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4fe5291d-32c3-4e2b-b7c9-761193d92e41 on host 12 at 290.5s.
# Adversary: Processed EXPLOIT_VULN 4fe5291d-32c3-4e2b-b7c9-761193d92e41 on host 12 at 308.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0f8d854b-9db4-4f07-a104-209f6fb5cb04 on host 12 at 308.1s.
# MTD: IPShuffle finished in 110.4s at 311.4s.
# MTD: Interrupted EXPLOIT_VULN at 311.4s!
# Adversary: Restarting with SCAN_HOST at 332.6s!
# Adversary: Start SCAN_HOST at 332.6s.
# Adversary: Processed SCAN_HOST at 337.6s.
# Adversary: Start ENUM_HOST at 337.6s.
# Adversary: Processed ENUM_HOST at 342.6s.
# Adversary: Start SCAN_PORT at 342.6s.
# Adversary: Processed SCAN_PORT at 367.6s.
# Adversary: Start EXPLOIT_VULN 4785a63d-4fa3-44b7-9a64-3c9c7fb568bb on host 7 at 367.6s.
# Adversary: Processed EXPLOIT_VULN 4785a63d-4fa3-44b7-9a64-3c9c7fb568bb on host 7 at 369.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d37646c0-9b54-4f0b-8c97-4bb6995c8be5 on host 7 at 369.2s.
# Adversary: Processed EXPLOIT_VULN d37646c0-9b54-4f0b-8c97-4bb6995c8be5 on host 7 at 373.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ef761983-c91b-43d6-9f71-77e467dc46f7 on host 7 at 373.0s.
# Adversary: Processed EXPLOIT_VULN ef761983-c91b-43d6-9f71-77e467dc46f7 on host 7 at 375.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 136bb299-e13c-4438-8644-c0bbccc87244 on host 7 at 375.9s.
# Adversary: Processed EXPLOIT_VULN 136bb299-e13c-4438-8644-c0bbccc87244 on host 7 at 380.1s.
# Adversary: Start EXPLOIT_VULN 5aa3a83c-d948-4f33-83f6-65bfc67a31d1 on host 7 at 380.1s.
# Adversary: Processed EXPLOIT_VULN 5aa3a83c-d948-4f33-83f6-65bfc67a31d1 on host 7 at 388.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 20b9e43f-eee7-4ef0-87f5-003c6277ada2 on host 7 at 388.6s.
# Adversary: Processed EXPLOIT_VULN 20b9e43f-eee7-4ef0-87f5-003c6277ada2 on host 7 at 390.0s.
# Adversary: Start EXPLOIT_VULN 878b32ba-4bb0-436b-9086-9f72e69aa6e3 on host 7 at 390.0s.
# Adversary: Processed EXPLOIT_VULN 878b32ba-4bb0-436b-9086-9f72e69aa6e3 on host 7 at 392.2s.
# Adversary: Start EXPLOIT_VULN eb7611cc-0e4c-4e29-92e2-6cbd2159ca14 on host 7 at 392.2s.
# Adversary: Processed EXPLOIT_VULN eb7611cc-0e4c-4e29-92e2-6cbd2159ca14 on host 7 at 394.4s.
# Adversary: Start EXPLOIT_VULN 0c475db0-05a3-4f94-ba78-97be18c2d664 on host 7 at 394.4s.
# MTD: IPShuffle triggered 401.3s
# MTD: IPShuffle deployed in the network at 401.3s.
# Adversary: Processed EXPLOIT_VULN 0c475db0-05a3-4f94-ba78-97be18c2d664 on host 7 at 402.2s.
# Adversary: Start EXPLOIT_VULN fa836cec-e2b2-4812-b766-c3007f697e27 on host 7 at 402.2s.
# Adversary: Processed EXPLOIT_VULN fa836cec-e2b2-4812-b766-c3007f697e27 on host 7 at 411.9s.
# Adversary: Start EXPLOIT_VULN 410b2be6-b204-4f8d-82e8-bd040e7038f2 on host 7 at 411.9s.
# Adversary: Processed EXPLOIT_VULN 410b2be6-b204-4f8d-82e8-bd040e7038f2 on host 7 at 420.2s.
# Adversary: Start EXPLOIT_VULN bf47011c-b116-46bf-b428-46ace3f658b1 on host 7 at 420.2s.
# Adversary: Processed EXPLOIT_VULN bf47011c-b116-46bf-b428-46ace3f658b1 on host 7 at 422.8s.
# Adversary: Start EXPLOIT_VULN d5f9a7b3-5e2a-41b9-8a44-04f6adaa198a on host 7 at 422.8s.
# Adversary: Processed EXPLOIT_VULN d5f9a7b3-5e2a-41b9-8a44-04f6adaa198a on host 7 at 429.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8d9f7765-64a3-4dc3-9fe1-36c4aadef614 on host 7 at 429.0s.
# Adversary: Processed EXPLOIT_VULN 8d9f7765-64a3-4dc3-9fe1-36c4aadef614 on host 7 at 434.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 7 at 434.3s.
# Adversary: Processed EXPLOIT_VULN 9c86b5fd-514e-4a25-a9b1-f83bccad7245 on host 7 at 442.4s.
# Adversary: Host 7 has been compromised at 442.4s!
# Adversary: Start SCAN_NEIGHBOR at 442.4s.
# Adversary: Processed SCAN_NEIGHBOR at 447.4s.
# Adversary: Start ENUM_HOST at 447.4s.
# Adversary: Processed ENUM_HOST at 452.4s.
# Adversary: Start SCAN_PORT at 452.4s.
# Adversary: Processed SCAN_PORT at 477.4s.
# Adversary: Start EXPLOIT_VULN 33b4381e-e889-4673-a4ff-e5231d3f6712 on host 13 at 477.4s.
# Adversary: Processed EXPLOIT_VULN 33b4381e-e889-4673-a4ff-e5231d3f6712 on host 13 at 479.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 55299269-5b68-4d2a-ad6b-15fdeef6bc00 on host 13 at 479.3s.
# Adversary: Processed EXPLOIT_VULN 55299269-5b68-4d2a-ad6b-15fdeef6bc00 on host 13 at 483.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7a804a7a-5901-4d81-a9e8-96bfb075aa56 on host 13 at 483.9s.
# Adversary: Processed EXPLOIT_VULN 7a804a7a-5901-4d81-a9e8-96bfb075aa56 on host 13 at 486.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 572b4f16-a25a-4873-9a30-b4ec8bd98191 on host 13 at 486.5s.
# Adversary: Processed EXPLOIT_VULN 572b4f16-a25a-4873-9a30-b4ec8bd98191 on host 13 at 489.8s.
# Adversary: Start EXPLOIT_VULN d9aa0592-4e3e-4d27-873e-8fddc4882c59 on host 13 at 489.8s.
# Adversary: Processed EXPLOIT_VULN d9aa0592-4e3e-4d27-873e-8fddc4882c59 on host 13 at 492.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN dba9f1dc-07e4-49f1-9da8-1d6c03024b89 on host 13 at 492.2s.
# Adversary: Processed EXPLOIT_VULN dba9f1dc-07e4-49f1-9da8-1d6c03024b89 on host 13 at 495.3s.
# Adversary: Start EXPLOIT_VULN ed0046fa-25fd-4ba8-9732-cd0d58786602 on host 13 at 495.3s.
# Adversary: Processed EXPLOIT_VULN ed0046fa-25fd-4ba8-9732-cd0d58786602 on host 13 at 496.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8fa33727-29e4-424f-b9a7-c42d1f7a74a2 on host 13 at 496.7s.
# Adversary: Processed EXPLOIT_VULN 8fa33727-29e4-424f-b9a7-c42d1f7a74a2 on host 13 at 499.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f84247cb-573e-4106-ab40-2cf36ca9ee3c on host 13 at 499.4s.
# Adversary: Processed EXPLOIT_VULN f84247cb-573e-4106-ab40-2cf36ca9ee3c on host 13 at 508.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7831238b-0441-4749-89d4-52879b7ed368 on host 13 at 508.1s.
# MTD: IPShuffle finished in 111.5s at 512.8s.
# MTD: Interrupted EXPLOIT_VULN at 512.8s!
# Adversary: Restarting with SCAN_HOST at 533.0s!
# Adversary: Start SCAN_HOST at 533.0s.
# Adversary: Processed SCAN_HOST at 538.0s.
# Adversary: Start ENUM_HOST at 538.0s.
# Adversary: Processed ENUM_HOST at 543.0s.
# Adversary: Start SCAN_PORT at 543.0s.
# Adversary: Processed SCAN_PORT at 568.0s.
# Adversary: Start EXPLOIT_VULN 0f8d854b-9db4-4f07-a104-209f6fb5cb04 on host 12 at 568.0s.
# Adversary: Processed EXPLOIT_VULN 0f8d854b-9db4-4f07-a104-209f6fb5cb04 on host 12 at 587.2s.
# Adversary: Start EXPLOIT_VULN 7dc76f9e-42cb-4133-8598-e8d2e69d0f06 on host 12 at 587.2s.
# Adversary: Processed EXPLOIT_VULN 7dc76f9e-42cb-4133-8598-e8d2e69d0f06 on host 12 at 589.4s.
# Adversary: Start EXPLOIT_VULN 56a5437d-3b46-474a-a66f-b0c769b0f244 on host 12 at 589.4s.
# Adversary: Processed EXPLOIT_VULN 56a5437d-3b46-474a-a66f-b0c769b0f244 on host 12 at 593.1s.
# Adversary: Start EXPLOIT_VULN e038558b-5186-4bc8-8fa2-b45b5cc2f591 on host 12 at 593.1s.
# Adversary: Processed EXPLOIT_VULN e038558b-5186-4bc8-8fa2-b45b5cc2f591 on host 12 at 603.0s.
# Adversary: Start BRUTE_FORCE at 603.0s.
# MTD: ServiceDiversity triggered 603.3s
# MTD: ServiceDiversity deployed in the network at 603.3s.
# Adversary: Processed BRUTE_FORCE at 623.0s.
# Adversary: Start ENUM_HOST at 623.0s.
# Adversary: Processed ENUM_HOST at 628.0s.
# Adversary: Start SCAN_PORT at 628.0s.
# Adversary: Processed SCAN_PORT at 653.0s.
# Adversary: Start EXPLOIT_VULN 46ed77cb-c79d-40e9-adfd-fcc7f7131ed7 on host 11 at 653.0s.
# Adversary: Processed EXPLOIT_VULN 46ed77cb-c79d-40e9-adfd-fcc7f7131ed7 on host 11 at 655.9s.
# Adversary: Start EXPLOIT_VULN 44c82b68-d3f4-4a23-b570-629c75725c0e on host 11 at 655.9s.
# Adversary: Processed EXPLOIT_VULN 44c82b68-d3f4-4a23-b570-629c75725c0e on host 11 at 659.5s.
# Adversary: Start EXPLOIT_VULN 3c91d030-1ab9-45bd-9ae5-99bd0a8cd3c8 on host 11 at 659.5s.
# Adversary: Processed EXPLOIT_VULN 3c91d030-1ab9-45bd-9ae5-99bd0a8cd3c8 on host 11 at 664.3s.
# Adversary: Start EXPLOIT_VULN 5a2054fc-90fc-42dc-a342-ed3bfc7eeb84 on host 11 at 664.3s.
# Adversary: Processed EXPLOIT_VULN 5a2054fc-90fc-42dc-a342-ed3bfc7eeb84 on host 11 at 667.2s.
# Adversary: Start EXPLOIT_VULN 2c411fde-3a6b-47d4-b953-1c4e438b0932 on host 11 at 667.2s.
# Adversary: Processed EXPLOIT_VULN 2c411fde-3a6b-47d4-b953-1c4e438b0932 on host 11 at 673.1s.
# Adversary: Start EXPLOIT_VULN caf264a6-a24c-4af8-8458-adf73f45cbca on host 11 at 673.1s.
# MTD: ServiceDiversity finished in 70.2s at 673.4s.
# MTD: Interrupted EXPLOIT_VULN at 673.4s!
# Adversary: Restarting with SCAN_PORT at 694.0s!
# Adversary: Start SCAN_PORT at 694.0s.
# Adversary: Processed SCAN_PORT at 719.0s.
# Adversary: Start EXPLOIT_VULN caf264a6-a24c-4af8-8458-adf73f45cbca on host 11 at 719.0s.
# Adversary: Processed EXPLOIT_VULN caf264a6-a24c-4af8-8458-adf73f45cbca on host 11 at 722.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7fb4f737-4c82-4a36-8f3b-095fe892564e on host 11 at 722.3s.
# Adversary: Processed EXPLOIT_VULN 7fb4f737-4c82-4a36-8f3b-095fe892564e on host 11 at 726.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN fb52d67b-f5d2-4d13-9b94-e64030cbee52 on host 11 at 726.3s.
# Adversary: Processed EXPLOIT_VULN fb52d67b-f5d2-4d13-9b94-e64030cbee52 on host 11 at 735.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 447af1aa-d93b-46f9-937f-12ef9d228e2a on host 11 at 735.5s.
# Adversary: Processed EXPLOIT_VULN 447af1aa-d93b-46f9-937f-12ef9d228e2a on host 11 at 742.3s.
# Adversary: Start EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 11 at 742.3s.
# Adversary: Processed EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 11 at 751.2s.
# Adversary: Start EXPLOIT_VULN 44c82b68-d3f4-4a23-b570-629c75725c0e on host 11 at 751.2s.
# Adversary: Processed EXPLOIT_VULN 44c82b68-d3f4-4a23-b570-629c75725c0e on host 11 at 755.1s.
# Adversary: Start EXPLOIT_VULN 0901b329-ea22-4ca3-91a2-f058ea80e934 on host 11 at 755.1s.
# Adversary: Processed EXPLOIT_VULN 0901b329-ea22-4ca3-91a2-f058ea80e934 on host 11 at 764.5s.
# Adversary: Start EXPLOIT_VULN 214f518a-e066-41c9-9f87-50addb0da391 on host 11 at 764.5s.
# Adversary: Processed EXPLOIT_VULN 214f518a-e066-41c9-9f87-50addb0da391 on host 11 at 771.2s.
# Adversary: Start EXPLOIT_VULN f3019f9e-678f-4c8d-9e86-554c734e294e on host 11 at 771.2s.
# Adversary: Processed EXPLOIT_VULN f3019f9e-678f-4c8d-9e86-554c734e294e on host 11 at 779.0s.
# Adversary: Start EXPLOIT_VULN 605caa72-ff71-4a7b-95bb-6504d821bcd5 on host 11 at 779.0s.
# Adversary: Processed EXPLOIT_VULN 605caa72-ff71-4a7b-95bb-6504d821bcd5 on host 11 at 781.0s.
# Adversary: Start EXPLOIT_VULN 6e943c09-6642-4365-9dcd-397b75a6817d on host 11 at 781.0s.
# Adversary: Processed EXPLOIT_VULN 6e943c09-6642-4365-9dcd-397b75a6817d on host 11 at 783.8s.
# Adversary: Start EXPLOIT_VULN 002a9b27-875c-479e-96db-b8c4342fded7 on host 11 at 783.8s.
# Adversary: Processed EXPLOIT_VULN 002a9b27-875c-479e-96db-b8c4342fded7 on host 11 at 791.6s.
# Adversary: Start EXPLOIT_VULN c69cf90a-98dd-48eb-9ea4-e3861529f1a7 on host 11 at 791.6s.
# Adversary: Processed EXPLOIT_VULN c69cf90a-98dd-48eb-9ea4-e3861529f1a7 on host 11 at 798.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0c475db0-05a3-4f94-ba78-97be18c2d664 on host 11 at 798.5s.
# MTD: IPShuffle triggered 803.4s
# MTD: IPShuffle deployed in the network at 803.4s.
# Adversary: Processed EXPLOIT_VULN 0c475db0-05a3-4f94-ba78-97be18c2d664 on host 11 at 806.6s.
# Adversary: Host 11 has been compromised at 806.6s!
# Adversary: Start SCAN_NEIGHBOR at 806.6s.
# Adversary: Processed SCAN_NEIGHBOR at 811.6s.
# Adversary: Start ENUM_HOST at 811.6s.
# Adversary: Processed ENUM_HOST at 816.6s.
# Adversary: Start SCAN_PORT at 816.6s.
# Adversary: Processed SCAN_PORT at 841.6s.
# Adversary: Start EXPLOIT_VULN 0f8d854b-9db4-4f07-a104-209f6fb5cb04 on host 12 at 841.6s.
# Adversary: Processed EXPLOIT_VULN 0f8d854b-9db4-4f07-a104-209f6fb5cb04 on host 12 at 861.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 56a5437d-3b46-474a-a66f-b0c769b0f244 on host 12 at 861.1s.
# Adversary: Processed EXPLOIT_VULN 56a5437d-3b46-474a-a66f-b0c769b0f244 on host 12 at 868.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e038558b-5186-4bc8-8fa2-b45b5cc2f591 on host 12 at 868.8s.
# Adversary: Processed EXPLOIT_VULN e038558b-5186-4bc8-8fa2-b45b5cc2f591 on host 12 at 876.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 12 has been compromised at 876.8s!
# Adversary: Start SCAN_NEIGHBOR at 876.8s.
# Adversary: Processed SCAN_NEIGHBOR at 881.8s.
# Adversary: Start ENUM_HOST at 881.8s.
# Adversary: Processed ENUM_HOST at 886.8s.
# Adversary: Start SCAN_PORT at 886.8s.
# Adversary: Processed SCAN_PORT at 911.8s.
# Adversary: Host 17 has been compromised at 911.8s!
# Adversary: Start SCAN_NEIGHBOR at 911.8s.
# MTD: IPShuffle finished in 110.7s at 914.1s.
# MTD: Interrupted SCAN_NEIGHBOR at 914.1s!
# Adversary: Restarting with SCAN_HOST at 934.1s!
# Adversary: Start SCAN_HOST at 934.1s.
# Adversary: Processed SCAN_HOST at 939.1s.
# Adversary: Start ENUM_HOST at 939.1s.
# Adversary: Processed ENUM_HOST at 944.1s.
# Adversary: Start SCAN_PORT at 944.1s.
# Adversary: Processed SCAN_PORT at 969.1s.
# Adversary: Start EXPLOIT_VULN 828d37f7-0489-4546-a679-7a54bc2f44ae on host 8 at 969.1s.
# Adversary: Processed EXPLOIT_VULN 828d37f7-0489-4546-a679-7a54bc2f44ae on host 8 at 970.2s.
# Adversary: Start EXPLOIT_VULN e5996886-9bb5-42d2-8b39-c1fb6c8899fc on host 8 at 970.2s.
# Adversary: Processed EXPLOIT_VULN e5996886-9bb5-42d2-8b39-c1fb6c8899fc on host 8 at 973.5s.
# Adversary: Start EXPLOIT_VULN 0f65c016-bce3-4497-8aad-04126e874847 on host 8 at 973.5s.
# Adversary: Processed EXPLOIT_VULN 0f65c016-bce3-4497-8aad-04126e874847 on host 8 at 977.4s.
# Adversary: Start EXPLOIT_VULN e922a03f-d704-4883-bbfb-d7ff996bfbd4 on host 8 at 977.4s.
# Adversary: Processed EXPLOIT_VULN e922a03f-d704-4883-bbfb-d7ff996bfbd4 on host 8 at 981.3s.
# Adversary: Start EXPLOIT_VULN 7b4cdbbe-6962-4578-800d-f854e58c2bd5 on host 8 at 981.3s.
# Adversary: Processed EXPLOIT_VULN 7b4cdbbe-6962-4578-800d-f854e58c2bd5 on host 8 at 986.9s.
# Adversary: Start EXPLOIT_VULN 7bdcc878-c605-412c-8366-fc3b1a58edd9 on host 8 at 986.9s.
# Adversary: Processed EXPLOIT_VULN 7bdcc878-c605-412c-8366-fc3b1a58edd9 on host 8 at 988.3s.
# Adversary: Start EXPLOIT_VULN 4135ac45-390d-4349-a519-c3f55d8b27c8 on host 8 at 988.3s.
# Adversary: Processed EXPLOIT_VULN 4135ac45-390d-4349-a519-c3f55d8b27c8 on host 8 at 990.5s.
# Adversary: Start EXPLOIT_VULN 364e6c46-4e81-4763-a785-14624b655070 on host 8 at 990.5s.
# Adversary: Processed EXPLOIT_VULN 364e6c46-4e81-4763-a785-14624b655070 on host 8 at 992.2s.
# Adversary: Start EXPLOIT_VULN 699e0e14-cb7d-4ade-80b0-18779d693cee on host 8 at 992.2s.
# Adversary: Processed EXPLOIT_VULN 699e0e14-cb7d-4ade-80b0-18779d693cee on host 8 at 999.5s.
# Adversary: Start EXPLOIT_VULN 908bc4fa-84dc-4251-8a19-c29a8a411a09 on host 8 at 999.5s.
# MTD: OSDiversity triggered 1004.0s
# MTD: OSDiversity deployed in the network at 1004.0s.
# Adversary: Processed EXPLOIT_VULN 908bc4fa-84dc-4251-8a19-c29a8a411a09 on host 8 at 1009.5s.
# Adversary: Start EXPLOIT_VULN 5967fb57-21eb-44eb-9992-b6115f8c3e4e on host 8 at 1009.5s.
# Adversary: Processed EXPLOIT_VULN 5967fb57-21eb-44eb-9992-b6115f8c3e4e on host 8 at 1011.6s.
# Adversary: Start EXPLOIT_VULN af91798c-57fc-420f-9010-c764d99e4763 on host 8 at 1011.6s.
# Adversary: Processed EXPLOIT_VULN af91798c-57fc-420f-9010-c764d99e4763 on host 8 at 1014.2s.
# Adversary: Start EXPLOIT_VULN d2ebd474-1931-42f0-a1fa-eecd2dacf116 on host 8 at 1014.2s.
# Adversary: Processed EXPLOIT_VULN d2ebd474-1931-42f0-a1fa-eecd2dacf116 on host 8 at 1020.6s.
# Adversary: Start EXPLOIT_VULN 5b159087-5198-48b8-980b-fc331e330542 on host 8 at 1020.6s.
# Adversary: Processed EXPLOIT_VULN 5b159087-5198-48b8-980b-fc331e330542 on host 8 at 1029.0s.
# Adversary: Start EXPLOIT_VULN 2e71dc6d-5ec9-4fbb-bf50-9d6fbcc100fa on host 8 at 1029.0s.
# Adversary: Processed EXPLOIT_VULN 2e71dc6d-5ec9-4fbb-bf50-9d6fbcc100fa on host 8 at 1047.7s.
# Adversary: Start EXPLOIT_VULN 1ca004b7-e7e5-44b8-b989-7883e45b30d5 on host 8 at 1047.7s.
# Adversary: Processed EXPLOIT_VULN 1ca004b7-e7e5-44b8-b989-7883e45b30d5 on host 8 at 1056.0s.
# Adversary: Start EXPLOIT_VULN bed51e2e-de14-4916-8df5-8020c750ad38 on host 8 at 1056.0s.
# Adversary: Processed EXPLOIT_VULN bed51e2e-de14-4916-8df5-8020c750ad38 on host 8 at 1056.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN af070d50-1b3a-4bed-bf60-f7406041b98d on host 8 at 1056.5s.
# Adversary: Processed EXPLOIT_VULN af070d50-1b3a-4bed-bf60-f7406041b98d on host 8 at 1057.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN aba16da2-2f1e-4284-8f9d-9025ec152efd on host 8 at 1057.0s.
# Adversary: Processed EXPLOIT_VULN aba16da2-2f1e-4284-8f9d-9025ec152efd on host 8 at 1063.9s.
# Adversary: Start EXPLOIT_VULN d1c70c32-98d9-4387-a6ee-1f3360c876bd on host 8 at 1063.9s.
# Adversary: Processed EXPLOIT_VULN d1c70c32-98d9-4387-a6ee-1f3360c876bd on host 8 at 1071.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 613c38aa-5586-48d3-8d17-cf2920f3669b on host 8 at 1071.4s.
# Adversary: Processed EXPLOIT_VULN 613c38aa-5586-48d3-8d17-cf2920f3669b on host 8 at 1077.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 8 has been compromised at 1077.4s!
# Adversary: Start SCAN_NEIGHBOR at 1077.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1082.4s.
# Adversary: Start ENUM_HOST at 1082.4s.
# MTD: OSDiversity finished in 80.8s at 1084.8s.
# Adversary: Processed ENUM_HOST at 1087.4s.
# Adversary: Start ENUM_HOST at 1087.4s.
# Adversary: Processed ENUM_HOST at 1092.4s.
# Adversary: Start ENUM_HOST at 1092.4s.
# Adversary: Processed ENUM_HOST at 1097.4s.
# Adversary: Start SCAN_PORT at 1097.4s.
# Adversary: Processed SCAN_PORT at 1122.4s.
# Adversary: Start EXPLOIT_VULN 798d5673-a649-4e1e-93dc-22671e2719b9 on host 21 at 1122.4s.
# Adversary: Processed EXPLOIT_VULN 798d5673-a649-4e1e-93dc-22671e2719b9 on host 21 at 1122.8s.
# Adversary: Start EXPLOIT_VULN 89c44eb4-51c2-4155-b03e-053d06f93dd1 on host 21 at 1122.8s.
# Adversary: Processed EXPLOIT_VULN 89c44eb4-51c2-4155-b03e-053d06f93dd1 on host 21 at 1127.8s.
# Adversary: Start EXPLOIT_VULN 002c16b8-7ee6-4c74-88df-d77da98780b1 on host 21 at 1127.8s.
# Adversary: Processed EXPLOIT_VULN 002c16b8-7ee6-4c74-88df-d77da98780b1 on host 21 at 1133.5s.
# Adversary: Start EXPLOIT_VULN d1740a74-d81a-457e-b294-7495e5d98ea2 on host 21 at 1133.5s.
# Adversary: Processed EXPLOIT_VULN d1740a74-d81a-457e-b294-7495e5d98ea2 on host 21 at 1134.2s.
# Adversary: Start EXPLOIT_VULN 572b4f16-a25a-4873-9a30-b4ec8bd98191 on host 21 at 1134.2s.
# Adversary: Processed EXPLOIT_VULN 572b4f16-a25a-4873-9a30-b4ec8bd98191 on host 21 at 1138.1s.
# Adversary: Start EXPLOIT_VULN a19a1719-0e5e-44f8-b40e-31d4b2d6259f on host 21 at 1138.1s.
# Adversary: Processed EXPLOIT_VULN a19a1719-0e5e-44f8-b40e-31d4b2d6259f on host 21 at 1144.2s.
# Adversary: Start EXPLOIT_VULN 3177f788-fed2-47b9-ab8c-4becb69568ed on host 21 at 1144.2s.
# Adversary: Processed EXPLOIT_VULN 3177f788-fed2-47b9-ab8c-4becb69568ed on host 21 at 1149.2s.
# Adversary: Start EXPLOIT_VULN 863d7b0d-a7c5-4bee-a4a5-745fc5683006 on host 21 at 1149.2s.
# Adversary: Processed EXPLOIT_VULN 863d7b0d-a7c5-4bee-a4a5-745fc5683006 on host 21 at 1157.9s.
# Adversary: Start EXPLOIT_VULN f23bea5e-ed7a-4f51-aab4-efce2b9953b3 on host 21 at 1157.9s.
# Adversary: Processed EXPLOIT_VULN f23bea5e-ed7a-4f51-aab4-efce2b9953b3 on host 21 at 1160.3s.
# Adversary: Start EXPLOIT_VULN 863d7b0d-a7c5-4bee-a4a5-745fc5683006 on host 21 at 1160.3s.
# Adversary: Processed EXPLOIT_VULN 863d7b0d-a7c5-4bee-a4a5-745fc5683006 on host 21 at 1164.7s.
# Adversary: Start EXPLOIT_VULN 43778cef-0497-4c7a-8c91-8fc36a96fa98 on host 21 at 1164.7s.
# Adversary: Processed EXPLOIT_VULN 43778cef-0497-4c7a-8c91-8fc36a96fa98 on host 21 at 1171.9s.
# Adversary: Start EXPLOIT_VULN 8dae48c8-8005-41f0-94ea-20869890d616 on host 21 at 1171.9s.
# Adversary: Processed EXPLOIT_VULN 8dae48c8-8005-41f0-94ea-20869890d616 on host 21 at 1179.4s.
# Adversary: Host 21 has been compromised at 1179.4s!
# Adversary: Start SCAN_NEIGHBOR at 1179.4s.
# Adversary: Processed SCAN_NEIGHBOR at 1184.4s.
# Adversary: Start ENUM_HOST at 1184.4s.
# Adversary: Processed ENUM_HOST at 1189.4s.
# Adversary: Start SCAN_PORT at 1189.4s.
# MTD: OSDiversity triggered 1204.1s
# MTD: OSDiversity deployed in the network at 1204.1s.
# Adversary: Processed SCAN_PORT at 1214.4s.
# Adversary: Start EXPLOIT_VULN f67b6932-c7fa-449e-9d01-42387a83d44b on host 37 at 1214.4s.
# Adversary: Processed EXPLOIT_VULN f67b6932-c7fa-449e-9d01-42387a83d44b on host 37 at 1215.6s.
# Adversary: Start EXPLOIT_VULN 9098ac7a-9673-4a95-8625-1ceface6a04f on host 37 at 1215.6s.
# Adversary: Processed EXPLOIT_VULN 9098ac7a-9673-4a95-8625-1ceface6a04f on host 37 at 1218.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1f434bc7-d77b-4b9e-9125-57479c68a3b1 on host 37 at 1218.0s.
# Adversary: Processed EXPLOIT_VULN 1f434bc7-d77b-4b9e-9125-57479c68a3b1 on host 37 at 1220.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 27c9e98a-2fe8-4694-abc3-413b719a60f1 on host 37 at 1220.0s.
# Adversary: Processed EXPLOIT_VULN 27c9e98a-2fe8-4694-abc3-413b719a60f1 on host 37 at 1226.8s.
# Adversary: Start EXPLOIT_VULN 791c80dd-888e-4a69-8c48-08e9a4ec0f67 on host 37 at 1226.8s.
# Adversary: Processed EXPLOIT_VULN 791c80dd-888e-4a69-8c48-08e9a4ec0f67 on host 37 at 1243.0s.
# Adversary: Start EXPLOIT_VULN 7a5daa91-a4a3-4e68-8ecf-18b35cb86b88 on host 37 at 1243.0s.
# Adversary: Processed EXPLOIT_VULN 7a5daa91-a4a3-4e68-8ecf-18b35cb86b88 on host 37 at 1247.8s.
# Adversary: Start EXPLOIT_VULN b38b6d9d-4146-4a09-9650-a58c380eec52 on host 37 at 1247.8s.
# Adversary: Processed EXPLOIT_VULN b38b6d9d-4146-4a09-9650-a58c380eec52 on host 37 at 1255.3s.
# Adversary: Start EXPLOIT_VULN a60756ba-b8f6-4ab3-9389-1467b2b8fc86 on host 37 at 1255.3s.
# Adversary: Processed EXPLOIT_VULN a60756ba-b8f6-4ab3-9389-1467b2b8fc86 on host 37 at 1275.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3b396384-e973-4f35-95ab-6ef1515df0a9 on host 37 at 1275.1s.
# MTD: OSDiversity finished in 82.9s at 1287.0s.
# MTD: Interrupted EXPLOIT_VULN at 1287.0s!
# Adversary: Restarting with SCAN_PORT at 1307.2s!
# Adversary: Start SCAN_PORT at 1307.2s.
# Adversary: Processed SCAN_PORT at 1332.2s.
# Adversary: Start EXPLOIT_VULN 7a5daa91-a4a3-4e68-8ecf-18b35cb86b88 on host 37 at 1332.2s.
# Adversary: Processed EXPLOIT_VULN 7a5daa91-a4a3-4e68-8ecf-18b35cb86b88 on host 37 at 1336.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b38b6d9d-4146-4a09-9650-a58c380eec52 on host 37 at 1336.8s.
# Adversary: Processed EXPLOIT_VULN b38b6d9d-4146-4a09-9650-a58c380eec52 on host 37 at 1346.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3b396384-e973-4f35-95ab-6ef1515df0a9 on host 37 at 1346.4s.
# Adversary: Processed EXPLOIT_VULN 3b396384-e973-4f35-95ab-6ef1515df0a9 on host 37 at 1363.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 71d30bbb-6d59-4b36-bc35-8e15dc8dbfd0 on host 37 at 1363.3s.
# Adversary: Processed EXPLOIT_VULN 71d30bbb-6d59-4b36-bc35-8e15dc8dbfd0 on host 37 at 1373.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 27c9e98a-2fe8-4694-abc3-413b719a60f1 on host 37 at 1373.9s.
# Adversary: Processed EXPLOIT_VULN 27c9e98a-2fe8-4694-abc3-413b719a60f1 on host 37 at 1379.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 791c80dd-888e-4a69-8c48-08e9a4ec0f67 on host 37 at 1379.1s.
# Adversary: Processed EXPLOIT_VULN 791c80dd-888e-4a69-8c48-08e9a4ec0f67 on host 37 at 1395.6s.
# Adversary: Host 37 has been compromised at 1395.6s!
# Adversary: Start SCAN_NEIGHBOR at 1395.6s.
# Adversary: Processed SCAN_NEIGHBOR at 1400.6s.
# Adversary: Start ENUM_HOST at 1400.6s.
# MTD: IPShuffle triggered 1404.4s
# MTD: IPShuffle deployed in the network at 1404.4s.
# Adversary: Processed ENUM_HOST at 1405.6s.
# Adversary: Start SCAN_PORT at 1405.6s.
# Adversary: Processed SCAN_PORT at 1430.6s.
# Adversary: Start EXPLOIT_VULN 96127bc4-5804-4092-8c32-ccbffaf02386 on host 33 at 1430.6s.
# Adversary: Processed EXPLOIT_VULN 96127bc4-5804-4092-8c32-ccbffaf02386 on host 33 at 1431.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3982e3d8-57e9-46b8-b5ab-b08304e9bfcf on host 33 at 1431.8s.
# Adversary: Processed EXPLOIT_VULN 3982e3d8-57e9-46b8-b5ab-b08304e9bfcf on host 33 at 1433.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 886f52ab-bc2a-463b-9752-30947d345cab on host 33 at 1433.4s.
# Adversary: Processed EXPLOIT_VULN 886f52ab-bc2a-463b-9752-30947d345cab on host 33 at 1439.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 80cc4018-e545-4ea2-a92b-47aa34b58722 on host 33 at 1439.7s.
# Adversary: Processed EXPLOIT_VULN 80cc4018-e545-4ea2-a92b-47aa34b58722 on host 33 at 1447.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5f657f9-4186-49aa-8339-24fb1c127b7b on host 33 at 1447.7s.
# Adversary: Processed EXPLOIT_VULN f5f657f9-4186-49aa-8339-24fb1c127b7b on host 33 at 1457.2s.
# Adversary: Start EXPLOIT_VULN 2bebc05f-54a3-4a0c-bba3-dea213c559a9 on host 33 at 1457.2s.
# Adversary: Processed EXPLOIT_VULN 2bebc05f-54a3-4a0c-bba3-dea213c559a9 on host 33 at 1459.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 152a915a-45a1-401d-aec6-bf8dd4c66605 on host 33 at 1459.5s.
# Adversary: Processed EXPLOIT_VULN 152a915a-45a1-401d-aec6-bf8dd4c66605 on host 33 at 1460.3s.
# Adversary: Start EXPLOIT_VULN 0cb0d1a9-eb8c-435c-90ea-beb32c74a997 on host 33 at 1460.3s.
# Adversary: Processed EXPLOIT_VULN 0cb0d1a9-eb8c-435c-90ea-beb32c74a997 on host 33 at 1463.0s.
# Adversary: Start EXPLOIT_VULN 26af06b1-b14f-49fa-abc4-75237f6f7ba1 on host 33 at 1463.0s.
# Adversary: Processed EXPLOIT_VULN 26af06b1-b14f-49fa-abc4-75237f6f7ba1 on host 33 at 1466.7s.
# Adversary: Start EXPLOIT_VULN eb32f84e-e6be-470c-83b1-5931818907cc on host 33 at 1466.7s.
# Adversary: Processed EXPLOIT_VULN eb32f84e-e6be-470c-83b1-5931818907cc on host 33 at 1472.3s.
# Adversary: Start EXPLOIT_VULN 0e92b525-5fd8-4379-ad9c-689b26ae15e5 on host 33 at 1472.3s.
# Adversary: Processed EXPLOIT_VULN 0e92b525-5fd8-4379-ad9c-689b26ae15e5 on host 33 at 1473.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9b55e3b4-ee3b-47ae-94bf-24a808116247 on host 33 at 1473.3s.
# Adversary: Processed EXPLOIT_VULN 9b55e3b4-ee3b-47ae-94bf-24a808116247 on host 33 at 1475.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 74e3032e-d7f4-4c0d-8fd1-5a98b88e4d75 on host 33 at 1475.1s.
# Adversary: Processed EXPLOIT_VULN 74e3032e-d7f4-4c0d-8fd1-5a98b88e4d75 on host 33 at 1481.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cbf67f2f-08aa-453a-a8f8-00777c6ab476 on host 33 at 1481.0s.
# Adversary: Processed EXPLOIT_VULN cbf67f2f-08aa-453a-a8f8-00777c6ab476 on host 33 at 1486.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f703b0c9-e028-4739-a644-e35e701f2d37 on host 33 at 1486.2s.
# Adversary: Processed EXPLOIT_VULN f703b0c9-e028-4739-a644-e35e701f2d37 on host 33 at 1489.6s.
# Adversary: Start EXPLOIT_VULN 3183cd02-86cc-4c5b-8bce-561ea9fa05e9 on host 33 at 1489.6s.
# Adversary: Processed EXPLOIT_VULN 3183cd02-86cc-4c5b-8bce-561ea9fa05e9 on host 33 at 1490.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2e497d94-2154-4273-87d4-838565df778f on host 33 at 1490.9s.
# Adversary: Processed EXPLOIT_VULN 2e497d94-2154-4273-87d4-838565df778f on host 33 at 1492.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN db74296f-ccfc-45da-ab4c-63499b16eebb on host 33 at 1492.0s.
# Adversary: Processed EXPLOIT_VULN db74296f-ccfc-45da-ab4c-63499b16eebb on host 33 at 1494.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 88402854-0d9d-436e-b8f3-154f22d4313c on host 33 at 1494.0s.
# Adversary: Processed EXPLOIT_VULN 88402854-0d9d-436e-b8f3-154f22d4313c on host 33 at 1500.2s.
# Adversary: Start EXPLOIT_VULN 59f05ea8-716d-491d-9678-73ac87366dda on host 33 at 1500.2s.
# Adversary: Processed EXPLOIT_VULN 59f05ea8-716d-491d-9678-73ac87366dda on host 33 at 1507.9s.
# Adversary: Start EXPLOIT_VULN 8ce7a51e-db0f-46b2-80de-187c55c4d6a8 on host 33 at 1507.9s.
# Adversary: Processed EXPLOIT_VULN 8ce7a51e-db0f-46b2-80de-187c55c4d6a8 on host 33 at 1509.7s.
# Adversary: Start EXPLOIT_VULN 9ae5dd34-0f86-4b96-9913-9477a3d259f3 on host 33 at 1509.7s.
# Adversary: Processed EXPLOIT_VULN 9ae5dd34-0f86-4b96-9913-9477a3d259f3 on host 33 at 1512.2s.
# Adversary: Start EXPLOIT_VULN 84834c1f-02b2-4808-a1c9-c25cbd979649 on host 33 at 1512.2s.
# Adversary: Processed EXPLOIT_VULN 84834c1f-02b2-4808-a1c9-c25cbd979649 on host 33 at 1515.0s.
# Adversary: Start EXPLOIT_VULN b52751f3-0fe7-4e4a-9a1a-4c7f97c24534 on host 33 at 1515.0s.
# MTD: IPShuffle finished in 111.9s at 1516.3s.
# MTD: Interrupted EXPLOIT_VULN at 1516.3s!
# Adversary: Restarting with SCAN_HOST at 1536.6s!
# Adversary: Start SCAN_HOST at 1536.6s.
# Adversary: Processed SCAN_HOST at 1541.6s.
# Adversary: Start ENUM_HOST at 1541.6s.
# Adversary: Processed ENUM_HOST at 1546.6s.
# Adversary: Start SCAN_PORT at 1546.6s.
# Adversary: Processed SCAN_PORT at 1571.6s.
# Adversary: Start EXPLOIT_VULN 0afcc73a-fa10-4930-830f-deec3e64cfdd on host 15 at 1571.6s.
# Adversary: Processed EXPLOIT_VULN 0afcc73a-fa10-4930-830f-deec3e64cfdd on host 15 at 1577.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 35fb0429-1009-4816-a47c-d9e5da5c32e3 on host 15 at 1577.3s.
# Adversary: Processed EXPLOIT_VULN 35fb0429-1009-4816-a47c-d9e5da5c32e3 on host 15 at 1583.4s.
# Adversary: Start EXPLOIT_VULN b328f025-fa64-4823-ac89-4e4ec8314f3d on host 15 at 1583.4s.
# Adversary: Processed EXPLOIT_VULN b328f025-fa64-4823-ac89-4e4ec8314f3d on host 15 at 1597.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 878b32ba-4bb0-436b-9086-9f72e69aa6e3 on host 15 at 1597.2s.
# Adversary: Processed EXPLOIT_VULN 878b32ba-4bb0-436b-9086-9f72e69aa6e3 on host 15 at 1602.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN eb7611cc-0e4c-4e29-92e2-6cbd2159ca14 on host 15 at 1602.6s.
# Adversary: Processed EXPLOIT_VULN eb7611cc-0e4c-4e29-92e2-6cbd2159ca14 on host 15 at 1604.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 70769c4f-15f1-4d7c-81c3-476386587e74 on host 15 at 1604.0s.
# MTD: ServiceDiversity triggered 1604.7s
# MTD: ServiceDiversity deployed in the network at 1604.7s.
# Adversary: Processed EXPLOIT_VULN 70769c4f-15f1-4d7c-81c3-476386587e74 on host 15 at 1627.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e11315ac-4a53-4dc4-be17-e85885a1b8a6 on host 15 at 1627.0s.
# Adversary: Processed EXPLOIT_VULN e11315ac-4a53-4dc4-be17-e85885a1b8a6 on host 15 at 1634.0s.
# Adversary: Start EXPLOIT_VULN 7a64499c-9991-4fbe-b8e8-46897144dfea on host 15 at 1634.0s.
# Adversary: Processed EXPLOIT_VULN 7a64499c-9991-4fbe-b8e8-46897144dfea on host 15 at 1638.6s.
# Adversary: Start EXPLOIT_VULN 7b6f55e5-ecf0-457b-99c7-3daac06f6035 on host 15 at 1638.6s.
# Adversary: Processed EXPLOIT_VULN 7b6f55e5-ecf0-457b-99c7-3daac06f6035 on host 15 at 1652.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6972d811-b2a5-435c-97ab-9e1346fad111 on host 15 at 1652.3s.
# Adversary: Processed EXPLOIT_VULN 6972d811-b2a5-435c-97ab-9e1346fad111 on host 15 at 1660.5s.
# Adversary: Start EXPLOIT_VULN 4f3e9b6d-e522-4bed-82c5-8945b848be54 on host 15 at 1660.5s.
# Adversary: Processed EXPLOIT_VULN 4f3e9b6d-e522-4bed-82c5-8945b848be54 on host 15 at 1669.4s.
# Adversary: Start EXPLOIT_VULN 5d0ad16d-92f2-444e-b513-fdd557af6f09 on host 15 at 1669.4s.
# MTD: ServiceDiversity finished in 71.9s at 1676.6s.
# MTD: Interrupted EXPLOIT_VULN at 1676.6s!
# Adversary: Restarting with SCAN_PORT at 1697.8s!
# Adversary: Start SCAN_PORT at 1697.8s.
# Adversary: Processed SCAN_PORT at 1722.8s.
# Adversary: Start EXPLOIT_VULN e11315ac-4a53-4dc4-be17-e85885a1b8a6 on host 15 at 1722.8s.
# Adversary: Processed EXPLOIT_VULN e11315ac-4a53-4dc4-be17-e85885a1b8a6 on host 15 at 1730.3s.
# Adversary: Start EXPLOIT_VULN 7a64499c-9991-4fbe-b8e8-46897144dfea on host 15 at 1730.3s.
# Adversary: Processed EXPLOIT_VULN 7a64499c-9991-4fbe-b8e8-46897144dfea on host 15 at 1734.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6972d811-b2a5-435c-97ab-9e1346fad111 on host 15 at 1734.9s.
# Adversary: Processed EXPLOIT_VULN 6972d811-b2a5-435c-97ab-9e1346fad111 on host 15 at 1743.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5d0ad16d-92f2-444e-b513-fdd557af6f09 on host 15 at 1743.4s.
# Adversary: Processed EXPLOIT_VULN 5d0ad16d-92f2-444e-b513-fdd557af6f09 on host 15 at 1750.6s.
# Adversary: Start EXPLOIT_VULN eeef2dc4-c6a1-4dc7-9cb7-59c812dcc406 on host 15 at 1750.6s.
# Adversary: Processed EXPLOIT_VULN eeef2dc4-c6a1-4dc7-9cb7-59c812dcc406 on host 15 at 1756.7s.
# Adversary: Host 15 has been compromised at 1756.7s!
# Adversary: Start SCAN_NEIGHBOR at 1756.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1761.7s.
# Adversary: Start ENUM_HOST at 1761.7s.
# Adversary: Processed ENUM_HOST at 1766.7s.
# Adversary: Start ENUM_HOST at 1766.7s.
# Adversary: Processed ENUM_HOST at 1771.7s.
# Adversary: Start ENUM_HOST at 1771.7s.
# Adversary: Processed ENUM_HOST at 1776.7s.
# Adversary: Start ENUM_HOST at 1776.7s.
# Adversary: Processed ENUM_HOST at 1781.7s.
# Adversary: Start ENUM_HOST at 1781.7s.
# Adversary: Processed ENUM_HOST at 1786.7s.
# Adversary: Start ENUM_HOST at 1786.7s.
# Adversary: Processed ENUM_HOST at 1791.7s.
# Adversary: Start SCAN_PORT at 1791.7s.
# MTD: CompleteTopologyShuffle triggered 1805.2s
# MTD: CompleteTopologyShuffle deployed in the network at 1805.2s.
# Adversary: Processed SCAN_PORT at 1816.7s.
# Adversary: Start EXPLOIT_VULN 8ee82118-bf9a-45c5-9c45-7990cae58bea on host 38 at 1816.7s.
# Adversary: Processed EXPLOIT_VULN 8ee82118-bf9a-45c5-9c45-7990cae58bea on host 38 at 1817.2s.
# Adversary: Start EXPLOIT_VULN 73124977-1d27-436d-a358-e2c50028021f on host 38 at 1817.2s.
# Adversary: Processed EXPLOIT_VULN 73124977-1d27-436d-a358-e2c50028021f on host 38 at 1823.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6f4a94ce-4e53-4b26-8272-ffdb4c8daf31 on host 38 at 1823.4s.
# Adversary: Processed EXPLOIT_VULN 6f4a94ce-4e53-4b26-8272-ffdb4c8daf31 on host 38 at 1830.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5cf0790f-04f1-4fe9-b8ba-5d0dd149fa53 on host 38 at 1830.4s.
# Adversary: Processed EXPLOIT_VULN 5cf0790f-04f1-4fe9-b8ba-5d0dd149fa53 on host 38 at 1831.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ff0fa8dd-3008-4f1f-8aee-bc4e57fd0862 on host 38 at 1831.4s.
# Adversary: Processed EXPLOIT_VULN ff0fa8dd-3008-4f1f-8aee-bc4e57fd0862 on host 38 at 1834.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8efff070-e6ef-4188-ac1d-d1274b7df923 on host 38 at 1834.3s.
# Adversary: Processed EXPLOIT_VULN 8efff070-e6ef-4188-ac1d-d1274b7df923 on host 38 at 1839.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6b783ec3-d100-4e8f-9b25-a2f3b2c61165 on host 38 at 1839.5s.
# Adversary: Processed EXPLOIT_VULN 6b783ec3-d100-4e8f-9b25-a2f3b2c61165 on host 38 at 1843.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5064b67d-6486-4df6-8273-e0bc1ac2ba49 on host 38 at 1843.9s.
# Adversary: Processed EXPLOIT_VULN 5064b67d-6486-4df6-8273-e0bc1ac2ba49 on host 38 at 1850.3s.
# Adversary: Start EXPLOIT_VULN 1365f03b-a2e1-43f1-a563-3681663d5482 on host 38 at 1850.3s.
# Adversary: Processed EXPLOIT_VULN 1365f03b-a2e1-43f1-a563-3681663d5482 on host 38 at 1855.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1348bf9c-9a24-4ecb-a393-c36e2517e03d on host 38 at 1855.4s.
# Adversary: Processed EXPLOIT_VULN 1348bf9c-9a24-4ecb-a393-c36e2517e03d on host 38 at 1857.4s.
# Adversary: Start EXPLOIT_VULN dbd2a9db-0bfd-4722-a8a6-8a0a1f37144e on host 38 at 1857.4s.
# Adversary: Processed EXPLOIT_VULN dbd2a9db-0bfd-4722-a8a6-8a0a1f37144e on host 38 at 1867.4s.
# Adversary: Start EXPLOIT_VULN 9bed401e-69a7-4a6d-b796-15891a27df18 on host 38 at 1867.4s.
# Adversary: Processed EXPLOIT_VULN 9bed401e-69a7-4a6d-b796-15891a27df18 on host 38 at 1873.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3c1ae97e-7d00-49e2-947d-277444748a53 on host 38 at 1873.5s.
# Adversary: Processed EXPLOIT_VULN 3c1ae97e-7d00-49e2-947d-277444748a53 on host 38 at 1879.4s.
# Adversary: Start EXPLOIT_VULN 1c0874f4-c716-47de-bb3e-a93890e39d7e on host 38 at 1879.4s.
# Adversary: Processed EXPLOIT_VULN 1c0874f4-c716-47de-bb3e-a93890e39d7e on host 38 at 1881.5s.
# Adversary: Start EXPLOIT_VULN 18a5ae50-fdd4-4209-90b4-29a597e7c1d7 on host 38 at 1881.5s.
# Adversary: Processed EXPLOIT_VULN 18a5ae50-fdd4-4209-90b4-29a597e7c1d7 on host 38 at 1884.3s.
# Adversary: Start EXPLOIT_VULN d8517ab4-3ac8-4edb-9a2a-614fe3c6c5ac on host 38 at 1884.3s.
# Adversary: Processed EXPLOIT_VULN d8517ab4-3ac8-4edb-9a2a-614fe3c6c5ac on host 38 at 1887.0s.
# Adversary: Start EXPLOIT_VULN 022cf91b-8459-4401-bc4e-53ed34971367 on host 38 at 1887.0s.
# Adversary: Processed EXPLOIT_VULN 022cf91b-8459-4401-bc4e-53ed34971367 on host 38 at 1894.7s.
# Adversary: Start EXPLOIT_VULN 4fe06488-a9e2-4ff8-91e5-88679c011adf on host 38 at 1894.7s.
# Adversary: Processed EXPLOIT_VULN 4fe06488-a9e2-4ff8-91e5-88679c011adf on host 38 at 1904.2s.
# Adversary: Start EXPLOIT_VULN 56a710b4-907b-4560-9494-e3d51ba7839d on host 38 at 1904.2s.
# Adversary: Processed EXPLOIT_VULN 56a710b4-907b-4560-9494-e3d51ba7839d on host 38 at 1911.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6d91d0f8-4a86-4ce6-b64b-636c493dc77a on host 38 at 1911.7s.
# MTD: CompleteTopologyShuffle finished in 120.0s at 1925.3s.
# MTD: Interrupted EXPLOIT_VULN at 1925.3s!
# Adversary: Restarting with SCAN_HOST at 1945.3s!
# Adversary: Start SCAN_HOST at 1945.3s.
# Adversary: Processed SCAN_HOST at 1950.3s.
# Adversary: Start ENUM_HOST at 1950.3s.
# Adversary: Processed ENUM_HOST at 1955.3s.
# Adversary: Start SCAN_PORT at 1955.3s.
# Adversary: Processed SCAN_PORT at 1980.3s.
# Adversary: Start EXPLOIT_VULN 0c08db1a-e183-4abf-b2d5-b0d7d57c3596 on host 26 at 1980.3s.
# Adversary: Processed EXPLOIT_VULN 0c08db1a-e183-4abf-b2d5-b0d7d57c3596 on host 26 at 1983.2s.
# Adversary: Start EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 26 at 1983.2s.
# Adversary: Processed EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 26 at 1991.7s.
# Adversary: Start EXPLOIT_VULN 3634a356-fea8-4945-bfb4-4aa8f8c0562f on host 26 at 1991.7s.
# Adversary: Processed EXPLOIT_VULN 3634a356-fea8-4945-bfb4-4aa8f8c0562f on host 26 at 1992.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN eec05958-58eb-41f4-9d65-154885676a3c on host 26 at 1992.2s.
# Adversary: Processed EXPLOIT_VULN eec05958-58eb-41f4-9d65-154885676a3c on host 26 at 1993.3s.
# Adversary: Start EXPLOIT_VULN cd16ba1e-3ad1-4daa-9d62-8a6c34b83eaf on host 26 at 1993.3s.
# Adversary: Processed EXPLOIT_VULN cd16ba1e-3ad1-4daa-9d62-8a6c34b83eaf on host 26 at 1997.2s.
# Adversary: Start EXPLOIT_VULN 0d1e2e78-fd1c-43ff-ae25-d02126f7be7c on host 26 at 1997.2s.
# MTD: ServiceDiversity triggered 2005.3s
# MTD: ServiceDiversity deployed in the network at 2005.3s.
# Adversary: Processed EXPLOIT_VULN 0d1e2e78-fd1c-43ff-ae25-d02126f7be7c on host 26 at 2007.4s.
# Adversary: Start EXPLOIT_VULN 54340eb3-cdfe-4459-835d-f25908aaf69b on host 26 at 2007.4s.
# Adversary: Processed EXPLOIT_VULN 54340eb3-cdfe-4459-835d-f25908aaf69b on host 26 at 2011.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b4be88b5-e1fa-44aa-9b22-e1e5bdc472a7 on host 26 at 2011.8s.
# Adversary: Processed EXPLOIT_VULN b4be88b5-e1fa-44aa-9b22-e1e5bdc472a7 on host 26 at 2019.4s.
# Adversary: Start EXPLOIT_VULN 9458c083-2e93-4fb7-9e9b-244b921c5e77 on host 26 at 2019.4s.
# Adversary: Processed EXPLOIT_VULN 9458c083-2e93-4fb7-9e9b-244b921c5e77 on host 26 at 2027.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 26 has been compromised at 2027.1s!
# Adversary: Start SCAN_NEIGHBOR at 2027.1s.
# Adversary: Processed SCAN_NEIGHBOR at 2032.1s.
# Adversary: Start ENUM_HOST at 2032.1s.
# Adversary: Processed ENUM_HOST at 2037.1s.
# Adversary: Start ENUM_HOST at 2037.1s.
# Adversary: Processed ENUM_HOST at 2042.1s.
# Adversary: Start ENUM_HOST at 2042.1s.
# Adversary: Processed ENUM_HOST at 2047.1s.
# Adversary: Start ENUM_HOST at 2047.1s.
# Adversary: Processed ENUM_HOST at 2052.1s.
# Adversary: Start SCAN_PORT at 2052.1s.
# MTD: ServiceDiversity finished in 70.2s at 2075.4s.
# MTD: Interrupted SCAN_PORT at 2075.4s!
# Adversary: Restarting with SCAN_PORT at 2095.8s!
# Adversary: Start SCAN_PORT at 2095.8s.
# Adversary: Processed SCAN_PORT at 2120.8s.
# Adversary: Start EXPLOIT_VULN 0e4e3c28-503e-4aba-8f97-b441be7cfdc9 on host 19 at 2120.8s.
# Adversary: Processed EXPLOIT_VULN 0e4e3c28-503e-4aba-8f97-b441be7cfdc9 on host 19 at 2124.3s.
# Adversary: Start EXPLOIT_VULN f9909fec-b298-41f4-9998-9aeb6f4abb73 on host 19 at 2124.3s.
# Adversary: Processed EXPLOIT_VULN f9909fec-b298-41f4-9998-9aeb6f4abb73 on host 19 at 2130.1s.
# Adversary: Start EXPLOIT_VULN 375d46b5-eab6-4cf3-83b0-3a7b7faa9fd6 on host 19 at 2130.1s.
# Adversary: Processed EXPLOIT_VULN 375d46b5-eab6-4cf3-83b0-3a7b7faa9fd6 on host 19 at 2139.0s.
# Adversary: Start EXPLOIT_VULN 29a68f53-cf7a-470b-9fa5-5244a396e36f on host 19 at 2139.0s.
# Adversary: Processed EXPLOIT_VULN 29a68f53-cf7a-470b-9fa5-5244a396e36f on host 19 at 2143.7s.
# Adversary: Start EXPLOIT_VULN 94edf2ae-eaa4-4993-9e35-a7659f4cd9ec on host 19 at 2143.7s.
# Adversary: Processed EXPLOIT_VULN 94edf2ae-eaa4-4993-9e35-a7659f4cd9ec on host 19 at 2150.0s.
# Adversary: Start EXPLOIT_VULN 46a8cebc-af43-4a11-9170-5f880f2252a5 on host 19 at 2150.0s.
# Adversary: Processed EXPLOIT_VULN 46a8cebc-af43-4a11-9170-5f880f2252a5 on host 19 at 2155.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 10837640-3590-4f87-ac3c-d7b8dd875040 on host 19 at 2155.6s.
# Adversary: Processed EXPLOIT_VULN 10837640-3590-4f87-ac3c-d7b8dd875040 on host 19 at 2163.2s.
# Adversary: Start EXPLOIT_VULN a83b1ae7-730e-4fec-a33c-19f21649cfc9 on host 19 at 2163.2s.
# Adversary: Processed EXPLOIT_VULN a83b1ae7-730e-4fec-a33c-19f21649cfc9 on host 19 at 2172.7s.
# Adversary: Start EXPLOIT_VULN 9f8dbe77-5a33-4af5-a701-83b68592d08e on host 19 at 2172.7s.
# Adversary: Processed EXPLOIT_VULN 9f8dbe77-5a33-4af5-a701-83b68592d08e on host 19 at 2182.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e9f88c44-234a-4353-878a-c8af092953d2 on host 19 at 2182.5s.
# Adversary: Processed EXPLOIT_VULN e9f88c44-234a-4353-878a-c8af092953d2 on host 19 at 2191.8s.
# Adversary: Start EXPLOIT_VULN fbed6bf4-a4c4-4ab4-91f5-1e938f510664 on host 19 at 2191.8s.
# Adversary: Processed EXPLOIT_VULN fbed6bf4-a4c4-4ab4-91f5-1e938f510664 on host 19 at 2201.1s.
# Adversary: Start EXPLOIT_VULN 2fb14e8b-76bf-45ba-94e6-75ac86388980 on host 19 at 2201.1s.
# Adversary: Processed EXPLOIT_VULN 2fb14e8b-76bf-45ba-94e6-75ac86388980 on host 19 at 2202.9s.
# Adversary: Start EXPLOIT_VULN b02c9e92-9b17-4392-9009-78bb8fce7217 on host 19 at 2202.9s.
# MTD: OSDiversity triggered 2205.4s
# MTD: OSDiversity deployed in the network at 2205.4s.
# Adversary: Processed EXPLOIT_VULN b02c9e92-9b17-4392-9009-78bb8fce7217 on host 19 at 2205.8s.
# Adversary: Start EXPLOIT_VULN f5c7afdf-fd44-481c-8a8d-981413761c93 on host 19 at 2205.8s.
# Adversary: Processed EXPLOIT_VULN f5c7afdf-fd44-481c-8a8d-981413761c93 on host 19 at 2214.8s.
# Adversary: Start EXPLOIT_VULN 10837640-3590-4f87-ac3c-d7b8dd875040 on host 19 at 2214.8s.
# Adversary: Processed EXPLOIT_VULN 10837640-3590-4f87-ac3c-d7b8dd875040 on host 19 at 2219.6s.
# Adversary: Start EXPLOIT_VULN a83b1ae7-730e-4fec-a33c-19f21649cfc9 on host 19 at 2219.6s.
# Adversary: Processed EXPLOIT_VULN a83b1ae7-730e-4fec-a33c-19f21649cfc9 on host 19 at 2223.8s.
# Adversary: Start BRUTE_FORCE at 2223.8s.
# Adversary: Processed BRUTE_FORCE at 2243.8s.
# Adversary: Start ENUM_HOST at 2243.8s.
# Adversary: Processed ENUM_HOST at 2248.8s.
# Adversary: Start SCAN_PORT at 2248.8s.
# Adversary: Processed SCAN_PORT at 2273.8s.
# Adversary: Start EXPLOIT_VULN 698af267-da0e-48ad-9216-feed3bb390a6 on host 42 at 2273.8s.
# MTD: OSDiversity finished in 80.7s at 2286.0s.
# MTD: Interrupted EXPLOIT_VULN at 2286.0s!
# Adversary: Restarting with SCAN_PORT at 2307.0s!
# Adversary: Start SCAN_PORT at 2307.0s.
# Adversary: Processed SCAN_PORT at 2332.0s.
# Adversary: Start EXPLOIT_VULN 698af267-da0e-48ad-9216-feed3bb390a6 on host 42 at 2332.0s.
# Adversary: Processed EXPLOIT_VULN 698af267-da0e-48ad-9216-feed3bb390a6 on host 42 at 2348.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ed555e8c-e0cc-42d3-b57c-17af78ff567d on host 42 at 2348.8s.
# Adversary: Processed EXPLOIT_VULN ed555e8c-e0cc-42d3-b57c-17af78ff567d on host 42 at 2351.6s.
# Adversary: Start EXPLOIT_VULN 1a627d67-e44c-4d15-a680-b07f0a803aa6 on host 42 at 2351.6s.
# Adversary: Processed EXPLOIT_VULN 1a627d67-e44c-4d15-a680-b07f0a803aa6 on host 42 at 2358.4s.
# Adversary: Start EXPLOIT_VULN ed555e8c-e0cc-42d3-b57c-17af78ff567d on host 42 at 2358.4s.
# Adversary: Processed EXPLOIT_VULN ed555e8c-e0cc-42d3-b57c-17af78ff567d on host 42 at 2361.7s.
# Adversary: Start EXPLOIT_VULN 1a627d67-e44c-4d15-a680-b07f0a803aa6 on host 42 at 2361.7s.
# Adversary: Processed EXPLOIT_VULN 1a627d67-e44c-4d15-a680-b07f0a803aa6 on host 42 at 2369.4s.
# Adversary: Start EXPLOIT_VULN 179d8414-ee9e-45ea-8d42-e3ba73ae5488 on host 42 at 2369.4s.
# Adversary: Processed EXPLOIT_VULN 179d8414-ee9e-45ea-8d42-e3ba73ae5488 on host 42 at 2378.7s.
# Adversary: Start EXPLOIT_VULN e664b8f6-48f7-4907-9f6b-38fef3733c4e on host 42 at 2378.7s.
# Adversary: Processed EXPLOIT_VULN e664b8f6-48f7-4907-9f6b-38fef3733c4e on host 42 at 2384.5s.
# Adversary: Start EXPLOIT_VULN f9c80387-4d40-44ef-8be5-8c2bb54f7ea5 on host 42 at 2384.5s.
# Adversary: Processed EXPLOIT_VULN f9c80387-4d40-44ef-8be5-8c2bb54f7ea5 on host 42 at 2389.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 675b0a61-fb6e-4012-adf3-372319c67eb3 on host 42 at 2389.7s.
# Adversary: Processed EXPLOIT_VULN 675b0a61-fb6e-4012-adf3-372319c67eb3 on host 42 at 2398.7s.
# Adversary: Start EXPLOIT_VULN c0397fea-0232-425c-ade2-c9de5ef02c44 on host 42 at 2398.7s.
# Adversary: Processed EXPLOIT_VULN c0397fea-0232-425c-ade2-c9de5ef02c44 on host 42 at 2398.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0c08db1a-e183-4abf-b2d5-b0d7d57c3596 on host 42 at 2398.7s.
# Adversary: Processed EXPLOIT_VULN 0c08db1a-e183-4abf-b2d5-b0d7d57c3596 on host 42 at 2401.7s.
# Adversary: Start EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 42 at 2401.7s.
# MTD: ServiceDiversity triggered 2405.6s
# MTD: ServiceDiversity deployed in the network at 2405.6s.
# Adversary: Processed EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 42 at 2410.1s.
# Adversary: Start EXPLOIT_VULN 447af1aa-d93b-46f9-937f-12ef9d228e2a on host 42 at 2410.1s.
# Adversary: Processed EXPLOIT_VULN 447af1aa-d93b-46f9-937f-12ef9d228e2a on host 42 at 2426.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 42 at 2426.4s.
# Adversary: Processed EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 42 at 2436.2s.
# Adversary: Host 42 has been compromised at 2436.2s!
# Adversary: Start SCAN_NEIGHBOR at 2436.2s.
# Adversary: Processed SCAN_NEIGHBOR at 2441.2s.
# Adversary: Start ENUM_HOST at 2441.2s.
# Adversary: Processed ENUM_HOST at 2446.2s.
# Adversary: Start SCAN_PORT at 2446.2s.
# Adversary: Processed SCAN_PORT at 2471.2s.
# Adversary: Host 39 has been compromised at 2471.2s!
# Adversary: Start SCAN_NEIGHBOR at 2471.2s.
# MTD: ServiceDiversity finished in 70.1s at 2475.7s.
# Adversary: Processed SCAN_NEIGHBOR at 2476.2s.
# Adversary: Start ENUM_HOST at 2476.2s.
# Adversary: Processed ENUM_HOST at 2481.2s.
# Adversary: Start SCAN_PORT at 2481.2s.
# Adversary: Processed SCAN_PORT at 2506.2s.
# Adversary: Start EXPLOIT_VULN dbd2a9db-0bfd-4722-a8a6-8a0a1f37144e on host 56 at 2506.2s.
# Adversary: Processed EXPLOIT_VULN dbd2a9db-0bfd-4722-a8a6-8a0a1f37144e on host 56 at 2517.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3c1ae97e-7d00-49e2-947d-277444748a53 on host 56 at 2517.0s.
# Adversary: Processed EXPLOIT_VULN 3c1ae97e-7d00-49e2-947d-277444748a53 on host 56 at 2521.7s.
# Adversary: Start EXPLOIT_VULN 127b6ee4-7fd3-4981-b514-4361f3f738cd on host 56 at 2521.7s.
# Adversary: Processed EXPLOIT_VULN 127b6ee4-7fd3-4981-b514-4361f3f738cd on host 56 at 2527.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN eb006c68-6192-4967-a706-4744e62aeba2 on host 56 at 2527.4s.
# Adversary: Processed EXPLOIT_VULN eb006c68-6192-4967-a706-4744e62aeba2 on host 56 at 2547.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b949e0e7-ce6a-489d-9ff3-1b75a1d28c95 on host 56 at 2547.1s.
# Adversary: Processed EXPLOIT_VULN b949e0e7-ce6a-489d-9ff3-1b75a1d28c95 on host 56 at 2560.2s.
# Adversary: Start EXPLOIT_VULN 7831238b-0441-4749-89d4-52879b7ed368 on host 56 at 2560.2s.
# Adversary: Processed EXPLOIT_VULN 7831238b-0441-4749-89d4-52879b7ed368 on host 56 at 2567.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 56 at 2567.4s.
# Adversary: Processed EXPLOIT_VULN 981eb72b-979d-4f06-9d8c-76c4a558904a on host 56 at 2576.2s.
# Adversary: Host 56 has been compromised at 2576.2s!
# Adversary: Start SCAN_NEIGHBOR at 2576.2s.
# Adversary: Processed SCAN_NEIGHBOR at 2581.2s.
# Adversary: Start ENUM_HOST at 2581.2s.
# Adversary: Processed ENUM_HOST at 2586.2s.
# Adversary: Start SCAN_PORT at 2586.2s.
# MTD: ServiceDiversity triggered 2607.4s
# MTD: ServiceDiversity deployed in the network at 2607.4s.
# Adversary: Processed SCAN_PORT at 2611.2s.
# Adversary: Start EXPLOIT_VULN d1740a74-d81a-457e-b294-7495e5d98ea2 on host 54 at 2611.2s.
# Adversary: Processed EXPLOIT_VULN d1740a74-d81a-457e-b294-7495e5d98ea2 on host 54 at 2612.4s.
# Adversary: Start EXPLOIT_VULN 675b0a61-fb6e-4012-adf3-372319c67eb3 on host 54 at 2612.4s.
# Adversary: Processed EXPLOIT_VULN 675b0a61-fb6e-4012-adf3-372319c67eb3 on host 54 at 2621.7s.
# Adversary: Start EXPLOIT_VULN 429e58b5-ca86-4f69-bed0-8bb59fe0bdb3 on host 54 at 2621.7s.
# Adversary: Processed EXPLOIT_VULN 429e58b5-ca86-4f69-bed0-8bb59fe0bdb3 on host 54 at 2621.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 40a2accb-0934-4032-b886-8c941b072404 on host 54 at 2621.9s.
# Adversary: Processed EXPLOIT_VULN 40a2accb-0934-4032-b886-8c941b072404 on host 54 at 2624.6s.
# Adversary: Start EXPLOIT_VULN 9b0d3816-faf3-4e50-bd02-6a3b8c7e41f8 on host 54 at 2624.6s.
# Adversary: Processed EXPLOIT_VULN 9b0d3816-faf3-4e50-bd02-6a3b8c7e41f8 on host 54 at 2634.5s.
# Adversary: Host 54 has been compromised at 2634.5s!
# Adversary: Start SCAN_NEIGHBOR at 2634.5s.
# Adversary: Processed SCAN_NEIGHBOR at 2639.5s.
# Adversary: Start ENUM_HOST at 2639.5s.
# Adversary: Processed ENUM_HOST at 2644.5s.
# Adversary: Start SCAN_PORT at 2644.5s.
# Adversary: Processed SCAN_PORT at 2669.5s.
# Adversary: Start EXPLOIT_VULN 481ce4a2-2a7c-43b2-bb80-e1d2ac2af6c9 on host 91 at 2669.5s.
# Adversary: Processed EXPLOIT_VULN 481ce4a2-2a7c-43b2-bb80-e1d2ac2af6c9 on host 91 at 2671.9s.
# Adversary: Start EXPLOIT_VULN b1eecde7-b730-41cb-96c5-b8d8177ef74a on host 91 at 2671.9s.
# MTD: ServiceDiversity finished in 70.1s at 2677.5s.
# MTD: Interrupted EXPLOIT_VULN at 2677.5s!
# Adversary: Restarting with SCAN_PORT at 2698.0s!
# Adversary: Start SCAN_PORT at 2698.0s.
# Adversary: Processed SCAN_PORT at 2723.0s.
# Adversary: Start EXPLOIT_VULN b1eecde7-b730-41cb-96c5-b8d8177ef74a on host 91 at 2723.0s.
# Adversary: Processed EXPLOIT_VULN b1eecde7-b730-41cb-96c5-b8d8177ef74a on host 91 at 2728.9s.
# Adversary: Start EXPLOIT_VULN 5ffb68a5-19d4-4a67-848d-e0bdfac607be on host 91 at 2728.9s.
# Adversary: Processed EXPLOIT_VULN 5ffb68a5-19d4-4a67-848d-e0bdfac607be on host 91 at 2732.5s.
# Adversary: Start EXPLOIT_VULN e1cd8b23-1a42-48ec-942b-fe492f146e84 on host 91 at 2732.5s.
# Adversary: Processed EXPLOIT_VULN e1cd8b23-1a42-48ec-942b-fe492f146e84 on host 91 at 2741.0s.
# Adversary: Start BRUTE_FORCE at 2741.0s.
# Adversary: Processed BRUTE_FORCE at 2761.0s.
# Adversary: Start ENUM_HOST at 2761.0s.
# Adversary: Processed ENUM_HOST at 2766.0s.
# Adversary: Start ENUM_HOST at 2766.0s.
# Adversary: Processed ENUM_HOST at 2771.0s.
# Adversary: Start SCAN_PORT at 2771.0s.
# Adversary: Processed SCAN_PORT at 2796.0s.
# Adversary: Start EXPLOIT_VULN 4646655c-b2de-4f9d-8b13-b77635519994 on host 43 at 2796.0s.
# Adversary: Processed EXPLOIT_VULN 4646655c-b2de-4f9d-8b13-b77635519994 on host 43 at 2798.7s.
# Adversary: Start EXPLOIT_VULN 6c9ced64-d677-4bdb-b176-2a407f171099 on host 43 at 2798.7s.
# Adversary: Processed EXPLOIT_VULN 6c9ced64-d677-4bdb-b176-2a407f171099 on host 43 at 2803.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 43 at 2803.9s.
# MTD: IPShuffle triggered 2809.6s
# MTD: IPShuffle deployed in the network at 2809.6s.
# Adversary: Processed EXPLOIT_VULN 0f7e3355-d153-4182-80be-f449c87d322f on host 43 at 2813.1s.
# Adversary: Start EXPLOIT_VULN 75bc1f5e-2b42-4d3c-b47c-ecffc7fd1bf4 on host 43 at 2813.1s.
# Adversary: Processed EXPLOIT_VULN 75bc1f5e-2b42-4d3c-b47c-ecffc7fd1bf4 on host 43 at 2813.9s.
# Adversary: Start EXPLOIT_VULN 52090caf-4626-4f88-8787-1bb092eff9d2 on host 43 at 2813.9s.
# Adversary: Processed EXPLOIT_VULN 52090caf-4626-4f88-8787-1bb092eff9d2 on host 43 at 2817.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a3ebca12-ae49-409a-bf4c-ffb24cf8c12f on host 43 at 2817.3s.
# Adversary: Processed EXPLOIT_VULN a3ebca12-ae49-409a-bf4c-ffb24cf8c12f on host 43 at 2825.8s.
# Adversary: Start EXPLOIT_VULN f04c6364-b5e5-4da9-ba0c-e87b270429e5 on host 43 at 2825.8s.
# Adversary: Processed EXPLOIT_VULN f04c6364-b5e5-4da9-ba0c-e87b270429e5 on host 43 at 2827.6s.
# Adversary: Start EXPLOIT_VULN bc812773-4bca-4e29-93ed-7aac4b8983ea on host 43 at 2827.6s.
# Adversary: Processed EXPLOIT_VULN bc812773-4bca-4e29-93ed-7aac4b8983ea on host 43 at 2836.1s.
# Adversary: Host 43 has been compromised at 2836.1s!
# Adversary: Start SCAN_NEIGHBOR at 2836.1s.
# Adversary: Processed SCAN_NEIGHBOR at 2841.1s.
# Adversary: Start ENUM_HOST at 2841.1s.
# Adversary: Processed ENUM_HOST at 2846.1s.
# Adversary: Start ENUM_HOST at 2846.1s.
# Adversary: Processed ENUM_HOST at 2851.1s.
# Adversary: Start SCAN_PORT at 2851.1s.
# Adversary: Processed SCAN_PORT at 2876.1s.
# Adversary: Start EXPLOIT_VULN 0cb0d1a9-eb8c-435c-90ea-beb32c74a997 on host 33 at 2876.1s.
# Adversary: Processed EXPLOIT_VULN 0cb0d1a9-eb8c-435c-90ea-beb32c74a997 on host 33 at 2878.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 26af06b1-b14f-49fa-abc4-75237f6f7ba1 on host 33 at 2878.5s.
# Adversary: Processed EXPLOIT_VULN 26af06b1-b14f-49fa-abc4-75237f6f7ba1 on host 33 at 2883.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f20a98ea-aae7-4a9b-b4f0-becea1623a22 on host 33 at 2883.0s.
# Adversary: Processed EXPLOIT_VULN f20a98ea-aae7-4a9b-b4f0-becea1623a22 on host 33 at 2890.7s.
# Adversary: Start EXPLOIT_VULN 41302133-bf4a-4495-a4b4-8ee8b7a57bcf on host 33 at 2890.7s.
# Adversary: Processed EXPLOIT_VULN 41302133-bf4a-4495-a4b4-8ee8b7a57bcf on host 33 at 2899.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7c024c4c-97ac-4e79-98b6-dbf2e2680735 on host 33 at 2899.0s.
# Adversary: Processed EXPLOIT_VULN 7c024c4c-97ac-4e79-98b6-dbf2e2680735 on host 33 at 2903.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f915f32b-a0a4-4413-818f-3892be6948bb on host 33 at 2903.2s.
# Adversary: Processed EXPLOIT_VULN f915f32b-a0a4-4413-818f-3892be6948bb on host 33 at 2906.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8bd89a70-6805-4ad7-b5d7-327fc3c1effa on host 33 at 2906.8s.
# Adversary: Processed EXPLOIT_VULN 8bd89a70-6805-4ad7-b5d7-327fc3c1effa on host 33 at 2915.0s.
# Adversary: Start EXPLOIT_VULN 3ddc711d-3223-446e-a667-4d6335e32126 on host 33 at 2915.0s.
# Adversary: Processed EXPLOIT_VULN 3ddc711d-3223-446e-a667-4d6335e32126 on host 33 at 2919.5s.
# Adversary: Start EXPLOIT_VULN f5f657f9-4186-49aa-8339-24fb1c127b7b on host 33 at 2919.5s.
# MTD: IPShuffle finished in 110.1s at 2919.7s.
# MTD: Interrupted EXPLOIT_VULN at 2919.7s!
# Adversary: Restarting with SCAN_HOST at 2939.8s!
# Adversary: Start SCAN_HOST at 2939.8s.
# Adversary: Processed SCAN_HOST at 2944.8s.
# Adversary: Start ENUM_HOST at 2944.8s.
# Adversary: Processed ENUM_HOST at 2949.8s.
# Adversary: Start SCAN_PORT at 2949.8s.
# Adversary: Processed SCAN_PORT at 2974.8s.
# Adversary: Start EXPLOIT_VULN fe7fd7ed-29c3-455c-8426-20be54ec3efa on host 5 at 2974.8s.
# Adversary: Processed EXPLOIT_VULN fe7fd7ed-29c3-455c-8426-20be54ec3efa on host 5 at 2979.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f4175450-8ea0-448d-b687-b58c2db3ec6a on host 5 at 2979.5s.
# Adversary: Processed EXPLOIT_VULN f4175450-8ea0-448d-b687-b58c2db3ec6a on host 5 at 2981.0s.
# Adversary: Start EXPLOIT_VULN d7b2bfd7-aeb7-4343-a51e-7ff38f8ea6c8 on host 5 at 2981.0s.
# Adversary: Processed EXPLOIT_VULN d7b2bfd7-aeb7-4343-a51e-7ff38f8ea6c8 on host 5 at 2992.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bca07adf-8fe5-4366-9848-780f2f151607 on host 5 at 2992.6s.
# Adversary: Processed EXPLOIT_VULN bca07adf-8fe5-4366-9848-780f2f151607 on host 5 at 2995.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN beff9658-1c2d-47b9-a263-c5c881a74387 on host 5 at 2995.6s.
# ENDED1

# %%
evaluation.get_network().graph.node_link_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6168e5d45d16> in <module>
# ----> 1 evaluation.get_network().graph.node_link_data()
#
# AttributeError: 'Graph' object has no attribute 'node_link_data'

# %%
evaluation.get_network().draw()
plt.show()

# %%
evaluation.visualise_mtd_operation()

# %%
evaluation.visualise_attack_operation_group_by_host()

# %%
evaluation.visualise_attack_operation()
# Out:
# total compromised hosts:  15

# %%
evaluation.compromise_record_by_attack_action()
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 8    EXPLOIT_VULN    63.078444    72.200282   9.121838             0
# 34   EXPLOIT_VULN   288.851656   294.233723   5.382068            13
# 74   EXPLOIT_VULN   636.265747   642.719167   6.453421             6
# 83   EXPLOIT_VULN   698.620898   702.144756   3.523858            18
# 120  EXPLOIT_VULN  1040.796905  1045.223176   4.426271             9
# 158  EXPLOIT_VULN  1261.427303  1264.289693   2.862391            23
# 170  EXPLOIT_VULN  1383.787226  1398.314597  14.527371            21
# 180  EXPLOIT_VULN  1468.286581  1488.936324  20.649743            11
# 188     SCAN_PORT  1552.750980  1577.750980  25.000000             5
# 197     SCAN_PORT  1617.750980  1642.750980  25.000000            24
# 205     SCAN_PORT  1703.186029  1728.186029  25.000000            28
# 215  EXPLOIT_VULN  1799.843918  1807.690236   7.846318            12
# 242  EXPLOIT_VULN  2061.581079  2071.310131   9.729051            22
# 262  EXPLOIT_VULN  2196.590908  2205.355502   8.764595             7
# 347  EXPLOIT_VULN  2819.855685  2825.844754   5.989069            17
#
#                         current_host_uuid compromise_host  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587               0
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec              13
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6               6
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7              18
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698               9
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34              23
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c              21
# 180  1c413663-0542-4ee9-b807-0bef4656aaff              11
# 188  ca9234f8-8134-4df2-b938-557d85816e55               5
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395              24
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f              28
# 215  59af67af-f26e-4829-beaf-e58136f81e61              12
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0              22
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1               7
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739              17
#
#                      compromise_host_uuid  current_host_attempt  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587                     1
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec                     2
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6                     2
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7                     1
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698                     1
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34                     1
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c                     1
# 180  1c413663-0542-4ee9-b807-0bef4656aaff                     2
# 188  ca9234f8-8134-4df2-b938-557d85816e55                     1
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395                     1
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f                     1
# 215  59af67af-f26e-4829-beaf-e58136f81e61                     2
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0                     1
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1                     1
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 8                      5                             0
# 34                    24                             1
# 74                    51                             2
# 83                    57                             3
# 120                   83                             4
# 158                  114                             5
# 170                  121                             6
# 180                  128                             7
# 188                  129                             8
# 197                  129                             9
# 205                  129                            10
# 215                  135                            11
# 242                  154                            12
# 262                  166                            13
# 347                  233                            14
#
#                                 compromise_users interrupted_in  \
# 8      [Bidget, Aurilia, Seline, Jermaine, Adah]           None
# 34           [Carmella, Chiarra, Prissie, Verna]           None
# 74         [Ellene, Max, Gilberte, Alie, Serena]           None
# 83   [Melonie, Lissi, Gianina, Quinn, Consolata]           None
# 120                  [Lori, Kaia, Casandra, Bev]           None
# 158             [Mair, Sherilyn, Nydia, Ariella]           None
# 170          [Christal, Christina, Talya, Timmy]           None
# 180          [Meagan, Krystalle, Freddi, Amelia]           None
# 188                  [Dulce, Kyla, Enid, Sherri]           None
# 197                         [Anna-Diane, Donica]           None
# 205                        [Kevyn, Kenna, Shela]           None
# 215                 [Anjanette, Silvana, Rozina]           None
# 242               [Gianna, Cheri, Kaycee, Karee]           None
# 262                      [Tandy, Judie, Stevana]           None
# 347                             [Joly, Antonina]           None
#
#     interrupted_by   color curr_host_token
# 8             None  yellow               1
# 34            None  yellow               2
# 74            None  yellow               4
# 83            None  yellow               6
# 120           None  yellow               8
# 158           None  yellow              10
# 170           None  yellow              11
# 180           None  yellow               7
# 188           None   green              13
# 197           None   green              14
# 205           None   green              15
# 215           None  yellow               9
# 242           None  yellow              16
# 262           None  yellow              17
# 347           None  yellow              20

# %%
evaluation.compromise_record_by_attack_action('SCAN_PORT')
# Out:
#           name   start_time  finish_time  duration  current_host  \
# 188  SCAN_PORT  1552.750980  1577.750980      25.0             5
# 197  SCAN_PORT  1617.750980  1642.750980      25.0            24
# 205  SCAN_PORT  1703.186029  1728.186029      25.0            28
#
#                         current_host_uuid compromise_host  \
# 188  ca9234f8-8134-4df2-b938-557d85816e55               5
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395              24
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f              28
#
#                      compromise_host_uuid  current_host_attempt  \
# 188  ca9234f8-8134-4df2-b938-557d85816e55                     1
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395                     1
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 188                  129                             8
# 197                  129                             9
# 205                  129                            10
#
#                 compromise_users interrupted_in interrupted_by  color  \
# 188  [Dulce, Kyla, Enid, Sherri]           None           None  green
# 197         [Anna-Diane, Donica]           None           None  green
# 205        [Kevyn, Kenna, Shela]           None           None  green
#
#     curr_host_token
# 188              13
# 197              14
# 205              15

# %%
evaluation.compromise_record_by_attack_action('EXPLOIT_VULN')
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 8    EXPLOIT_VULN    63.078444    72.200282   9.121838             0
# 34   EXPLOIT_VULN   288.851656   294.233723   5.382068            13
# 74   EXPLOIT_VULN   636.265747   642.719167   6.453421             6
# 83   EXPLOIT_VULN   698.620898   702.144756   3.523858            18
# 120  EXPLOIT_VULN  1040.796905  1045.223176   4.426271             9
# 158  EXPLOIT_VULN  1261.427303  1264.289693   2.862391            23
# 170  EXPLOIT_VULN  1383.787226  1398.314597  14.527371            21
# 180  EXPLOIT_VULN  1468.286581  1488.936324  20.649743            11
# 215  EXPLOIT_VULN  1799.843918  1807.690236   7.846318            12
# 242  EXPLOIT_VULN  2061.581079  2071.310131   9.729051            22
# 262  EXPLOIT_VULN  2196.590908  2205.355502   8.764595             7
# 347  EXPLOIT_VULN  2819.855685  2825.844754   5.989069            17
#
#                         current_host_uuid compromise_host  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587               0
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec              13
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6               6
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7              18
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698               9
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34              23
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c              21
# 180  1c413663-0542-4ee9-b807-0bef4656aaff              11
# 215  59af67af-f26e-4829-beaf-e58136f81e61              12
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0              22
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1               7
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739              17
#
#                      compromise_host_uuid  current_host_attempt  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587                     1
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec                     2
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6                     2
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7                     1
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698                     1
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34                     1
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c                     1
# 180  1c413663-0542-4ee9-b807-0bef4656aaff                     2
# 215  59af67af-f26e-4829-beaf-e58136f81e61                     2
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0                     1
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1                     1
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 8                      5                             0
# 34                    24                             1
# 74                    51                             2
# 83                    57                             3
# 120                   83                             4
# 158                  114                             5
# 170                  121                             6
# 180                  128                             7
# 215                  135                            11
# 242                  154                            12
# 262                  166                            13
# 347                  233                            14
#
#                                 compromise_users interrupted_in  \
# 8      [Bidget, Aurilia, Seline, Jermaine, Adah]           None
# 34           [Carmella, Chiarra, Prissie, Verna]           None
# 74         [Ellene, Max, Gilberte, Alie, Serena]           None
# 83   [Melonie, Lissi, Gianina, Quinn, Consolata]           None
# 120                  [Lori, Kaia, Casandra, Bev]           None
# 158             [Mair, Sherilyn, Nydia, Ariella]           None
# 170          [Christal, Christina, Talya, Timmy]           None
# 180          [Meagan, Krystalle, Freddi, Amelia]           None
# 215                 [Anjanette, Silvana, Rozina]           None
# 242               [Gianna, Cheri, Kaycee, Karee]           None
# 262                      [Tandy, Judie, Stevana]           None
# 347                             [Joly, Antonina]           None
#
#     interrupted_by   color curr_host_token
# 8             None  yellow               1
# 34            None  yellow               2
# 74            None  yellow               4
# 83            None  yellow               6
# 120           None  yellow               8
# 158           None  yellow              10
# 170           None  yellow              11
# 180           None  yellow               7
# 215           None  yellow               9
# 242           None  yellow              16
# 262           None  yellow              17
# 347           None  yellow              20

# %%
evaluation.compromise_record_by_attack_action('BRUTE_FORCE')
# Out:
# Empty DataFrame
# Columns: [name, start_time, finish_time, duration, current_host, current_host_uuid, compromise_host, compromise_host_uuid, current_host_attempt, cumulative_attempts, cumulative_compromised_hosts, compromise_users, interrupted_in, interrupted_by, color, curr_host_token]
# Index: []

# %%
evaluation.evaluation_result_by_compromise_checkpoint()
# Out:
# [{'time_to_compromise': 1292.1944692087566,
#   'attack_success_rate': 0.47619047619047616,
#   'host_compromise_ratio': 0.1,
#   'mtd_execution_frequency': 0.005216447423407677}]
